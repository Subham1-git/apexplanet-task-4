# %%
import os
current_directory=os.getcwd()
print(current_directory)
# Out:
# C:\Users\panda\OneDrive\Desktop\basic python

# %%
import numpy as np
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\panda\\OneDrive\\Desktop\\basic python'

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 957.9 kB/s eta 0:00:08
#    -- ------------------------------------- 0.5/8.1 MB 957.9 kB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.1 MB 663.6 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.1 MB 663.6 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/8.1 MB 652.3 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/8.1 MB 652.3 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.1 MB 650.6 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.1 MB 650.6 kB/s eta 0:00:11
#    ------- -------------------------------- 1.6/8.1 MB 685.4 kB/s eta 0:00:10
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3]
y=[5,6,8]
plt.plot(x,y)
plt.title("basic chart")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
x=[10,14,15]
y=[13,16,17]
plt.plot(x,y,marker="o",linestyle="-",color="green")
categoriecategorie()

# %%
categories=("categorie1","categorie2","categorie3","categorie4")
values=[10,15,17,20]
plt.bar(categories,values,color="orange")
plt.title("line chartt")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
data=[1,1,1,5,5,5,8,9,10]
plt.hist(data,bins=5,color='skyblue',edgecolor='black')
plt.title("histogram")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
group1=[10,11,19,28,]
group2=[1,5,6,9,]
group3=[15,18,20,27]
plt.boxplot([group1,group2,group3],labels=['group1','group2','group3'])
plt.title("box plot chart")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
# Out:
# C:\Users\panda\AppData\Local\Temp\ipykernel_2440\2519813573.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1,group2,group3],labels=['group1','group2','group3'])
